# %% [markdown]
# # Portfolio Optimization - Data Exploration
#
# This notebook explores the initial data collection and portfolio optimization implementation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from portfolio_optimization.data import DataCollector
from portfolio_optimization.optimization import PortfolioOptimizer

# Set up plotting style
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = [12, 6]  # Larger default figure size
plt.rcParams['axes.grid'] = True          # Always show grid
plt.rcParams['axes.spines.top'] = False   # Remove top spine
plt.rcParams['axes.spines.right'] = False # Remove right spine
sns.set_palette('husl')                   # Set color palette

# %% [markdown]
# ## 1. Data Collection and Preprocessing

# %%
# Initialize data collector
collector = DataCollector()

# Collect and process data
data = collector.process_data()
prices = data['prices']
returns = data['returns']['daily']

print(f"Data shape: {returns.shape}")
print(f"\nFirst few rows of returns:")
returns.head()
# Out:
# Successfully fetched data for AAPL
# Successfully fetched data for MSFT
# Successfully fetched data for GOOGL
# Successfully fetched data for AMZN
# Successfully fetched data for META
# Successfully fetched data for AGG
# Successfully fetched data for DBC
# Successfully fetched data for UUP
# Data shape: (2922, 8)
#
# First few rows of returns:
#                 AAPL      MSFT     GOOGL      AMZN      META       AGG  \
# Date
# 2012-05-21  0.058261  0.016399  0.022835  0.019921 -0.109861 -0.000180
# 2012-05-22 -0.007679  0.000336 -0.021674 -0.012746 -0.089039 -0.002433
# 2012-05-23  0.024400 -0.021841  0.014414  0.009056  0.032258  0.001174
# 2012-05-24 -0.009184 -0.001374 -0.009517 -0.009389  0.032187 -0.000812
# 2012-05-25 -0.005360 -0.000344 -0.020094 -0.010918 -0.033908  0.001535
#
#                  DBC       UUP
# Date
# 2012-05-21  0.013323 -0.003117
# 2012-05-22 -0.014275  0.010272
# 2012-05-23 -0.011052  0.003537
# 2012-05-24  0.000385  0.003965
# 2012-05-25  0.003467  0.001316

# %% [markdown]
# ### Data Quality Checks

# %%
# Check for missing values
print("Missing values:")
print(returns.isnull().sum())

# Basic statistics
print("\nBasic statistics:")
returns.describe()
# Out:
# Missing values:
# AAPL     0
# MSFT     0
# GOOGL    0
# AMZN     0
# META     0
# AGG      0
# DBC      0
# UUP      0
# dtype: int64
#
# Basic statistics:
#               AAPL         MSFT        GOOGL         AMZN         META  \
# count  2922.000000  2922.000000  2922.000000  2922.000000  2922.000000
# mean      0.001011     0.001089     0.000909     0.001116     0.001082
# std       0.017896     0.016751     0.017078     0.020377     0.025280
# min      -0.128647    -0.147390    -0.116342    -0.140494    -0.263901
# 25%      -0.007521    -0.006784    -0.007092    -0.008733    -0.010045
# 50%       0.000889     0.000734     0.000784     0.000935     0.000998
# 75%       0.010317     0.009481     0.009239     0.011422     0.012825
# max       0.119808     0.142169     0.162584     0.141311     0.296115
#
#                AGG          DBC          UUP
# count  2922.000000  2922.000000  2922.000000
# mean      0.000065     0.000026     0.000109
# std       0.003072     0.010764     0.004496
# min      -0.040011    -0.079444    -0.032070
# 25%      -0.001307    -0.005684    -0.002456
# 50%       0.000178     0.000625     0.000000
# 75%       0.001502     0.005959     0.002729
# max       0.023721     0.047990     0.037821

# %%
# Plot return distributions
plt.figure(figsize=(12, 6))
returns.hist(bins=50, alpha=0.5)
plt.title('Return Distributions')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
# Plot correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(returns.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Asset Correlation Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Portfolio Optimization

# %%
# Initialize optimizer
optimizer = PortfolioOptimizer()

# Optimize portfolio
result = optimizer.optimize_portfolio(returns)

print("Optimal Portfolio:")
print(f"Sharpe Ratio: {result['sharpe_ratio']:.2f}")
print(f"Annual Return: {result['return']:.2%}")
print(f"Annual Volatility: {result['volatility']:.2%}")

# Plot weights
plt.figure(figsize=(12, 6))
pd.Series(result['weights']).plot(kind='bar')
plt.title('Optimal Portfolio Weights')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Optimal Portfolio:
# Sharpe Ratio: 0.01
# Annual Return: 17.03%
# Annual Volatility: 946.18%

# %% [markdown]
# ## 3. Efficient Frontier

# %%
# Generate efficient frontier
ef = optimizer.generate_efficient_frontier(returns)

# Plot efficient frontier
plt.figure(figsize=(10, 6))
plt.scatter(ef['volatility'], ef['return'], c=ef['sharpe_ratio'], 
           cmap='viridis', marker='o')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Annualized Volatility')
plt.ylabel('Annualized Return')
plt.title('Efficient Frontier')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/Documents/Vanderbilt/Projects/Portfolio-Optimization/portfolio_optimization/optimization/optimizer.py:337, in PortfolioOptimizer.generate_efficient_frontier(self, returns, n_points)
#     336 if not efficient_portfolios:
# --> 337     raise Exception("Failed to generate any efficient frontier points")
#     339 # Create DataFrame and sort by return
#
# Exception: Failed to generate any efficient frontier points
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Generate efficient frontier
# ----> 2 ef = optimizer.generate_efficient_frontier(returns)
#       4 # Plot efficient frontier
#       5 plt.figure(figsize=(10, 6))
#
# File ~/Documents/Vanderbilt/Projects/Portfolio-Optimization/portfolio_optimization/optimization/optimizer.py:346, in PortfolioOptimizer.generate_efficient_frontier(self, returns, n_points)
#     343     return ef
#     345 except Exception as e:
# --> 346     raise Exception(f"Failed to generate efficient frontier: {str(e)}")
#
# Exception: Failed to generate efficient frontier: Failed to generate any efficient frontier points
